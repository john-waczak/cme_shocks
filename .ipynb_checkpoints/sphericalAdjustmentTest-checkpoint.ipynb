# %%
# %matplotlib notebook 
import numpy as np 
import matplotlib.pyplot as plt 
from __future__ import division 
from __future__ import print_function 
import os 
from glob import glob 
# imports for playing with fits files 
from sunpy.net import Fido, attrs
from datetime import datetime, timedelta
import astropy.units as u 
import sunpy.map as smap 
from astropy.coordinates import SkyCoord 
from scipy.interpolate import interp1d
from astropy.convolution import convolve, Box1DKernel
from datetime import datetime, timedelta
import matplotlib.dates as mdates
from AIA_tools import *

# %%
r0 = np.loadtxt('/data/khnum/REU2018/jwaczak/data/initialRadii.txt', delimiter=',')
print(r0)
dx = r0[0]/20
print(dx)
# Out:
# [142893.748565 219175.349416]
# 7144.687428249999

# %%
synthObs_files = glob('/data/khnum/REU2018/jwaczak/data/simOutput/*.txt')
print(synthObs_files)
# Out:
# ['/data/khnum/REU2018/jwaczak/data/simOutput/t0--1.80E+06__t1--2.80E+06__n--1.00E+08.txt']

# %%
t1 = 2.8e6
n = 8

outData1 = simulation.applySphericalCorrection(synthObs_files[1], dx, 1.8e6, t1, n)
outData2 = simulation.applySphericalCorrection(synthObs_files[0], dx, 1.3e6, t1, n)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-28e87e58b8bc> in <module>()
#       2 n = 8
#       3
# ----> 4 outData1 = simulation.applySphericalCorrection(synthObs_files[1], dx, 1.8e6, t1, n)
#       5 outData2 = simulation.applySphericalCorrection(synthObs_files[0], dx, 1.3e6, t1, n)
#
# IndexError: list index out of range

# %%
print(np.shape(outData1), outData1[:,2].max())
print(np.shape(outData2), outData2[:,2].max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5a0d3bf07dc8> in <module>()
# ----> 1 print(np.shape(outData1), outData1[:,2].max())
#       2 print(np.shape(outData2), outData2[:,2].max())
#
# NameError: name 'outData1' is not defined

# %%
t0 = 1e6
t1 = 2.8e6
n = 8
element_list = '2, 6, 7, 8, 10, 12, 13, 14, 16, 18, 20, 26, 28'  # He, C, N, O, Ne, Mg, Al, Si, S, Ar, Ca, Fe, Ni
fname = 't0--{:.2E}__t1--{:.2E}__n--{:.2E}'.format(t0, t1, 10**n)

simDataFile = simulation.run(t0, t1, 10**n, num=13,
                                             indices=element_list, ntime=20, dt= 12, filename=fname+'.dat')

print(simDataFile)
# Out:
# /data/khnum/REU2018/jwaczak/data/simRuns/t0--1.00E+06__t1--2.80E+06__n--1.00E+08.dat

# %%
obs, simParams = simulation.getSyntheticObservation_II(t0, t1, n, simDataFile)
# Out:
# 2
# 6
# 7
# 8
# 10
# 12
# 13
# 14
# 16
# 18
# 20
# 26
# 28

# %%
plt.figure() 
plt.plot(obs['time'], obs['193'])
plt.plot(obs['time'], obs['211'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = [[obs['time'][i], obs['171'][i], obs['193'][i], obs['211'][i], obs['304'][i], obs['335'][i]] for i in range(len(obs['time']))]
data = np.asarray(data)
np.savetxt('/data/khnum/REU2018/jwaczak/data/simOutput/'+fname+'.txt', data, delimiter=',', header='t0: {} t1: {} n: {} \n times, 171, 193, 211, 304, 335'.format(simParams[0], simParams[1], simParams[2]))

# %%
plt.figure()
plt.plot(data[:,0], data[:,1])
plt.plot(data[:,0], data[:,2])
plt.plot(data[:,0], data[:,3])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
r0 = np.loadtxt('/data/khnum/REU2018/jwaczak/data/initialRadii.txt', delimiter=',')
dx = r0[0]/20

corrected = simulation.applySphericalCorrection('/data/khnum/REU2018/jwaczak/data/simOutput/'+fname+'.txt', dx, t0, t1, n)
# Out:
# ((21, 6), (5,), (2,))
# (142893.748565, 286893.748565)
# 0
#   1
# 	42.1021235508
# 	44.3149030324
# 	9.53621870492
# 	0.995880448586
# 	0.324146522877
# 1
#   11
# 	29.2186731655
# 	30.7543315838
# 	6.61809034971
# 	0.691136286844
# 	0.22495614261
# 2
#   17
# 	24.5038491625
# 	25.7917085405
# 	5.55017288959
# 	0.579612196201
# 	0.188656457994
# 3
#   21
# 	21.2464327891
# 	22.3630907286
# 	4.81236129413
# 	0.502561515486
# 	0.163577433424
# 4
#   25
# 	18.7612830053
# 	19.7473278549
# 	4.24946969023
# 	0.443777970316
# 	0.144444131032
# 5
#   29
# 	16.7715706024
# 	17.6530412783
# 	3.79879568537
# 	0.396713463512
# 	0.12912522779
# 6
#   33
# 	15.1307050817
# 	15.9259360801
# 	3.42713622615
# 	0.357900554494
# 	0.116492115534
# 7
#   35
# 	13.749566037
# 	14.4722079144
# 	3.11430535488
# 	0.32523119591
# 	0.105858651442
# 8
#   39
# 	12.5691860412
# 	13.2297901777
# 	2.84694682651
# 	0.297310576698
# 	0.0967708421108
# 9
#   41
# 	11.5482489748
# 	12.1551952812
# 	2.61570245382
# ...

# %%
plt.figure() 
plt.plot(corrected[:,0], corrected[:,1])
plt.plot(corrected[:,0], corrected[:,2])
# Out:
# <img src="data:image/png;base64,..." width="640">
